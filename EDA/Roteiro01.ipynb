# %% [markdown]
# <a href="https://colab.research.google.com/github/thiagoguimaraes96-vwco/teste/blob/main/EDA/Roteiro01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Roteiro EDA**
# ## Utilizar este Notebook para executar os comandos.
# **Arquivo de referência:** *Roteiro EDA.docx*

# %%
import pandas as pd

# %%
data = 'https://raw.githubusercontent.com/rlrocha90/CursoVW/refs/heads/main/EDA/Auto%20Sales%20data.csv'

# %%
df = pd.read_csv(data)

# %%
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10168               36      96.66                1  3479.76
# ...           ...              ...        ...              ...      ...
# 2742        10350               20     112.22               15  2244.40
# 2743        10373               29     137.19                1  3978.51
# 2744        10386               43     125.99                4  5417.57
# 2745        10397               34      62.24                1  2116.16
# 2746        10414               47      65.52                9  3079.44
#
#        ORDERDATE  DAYS_SINCE_LASTORDER    STATUS  PRODUCTLINE  MSRP  \
# ...

# %%
df['ORDERNUMBER'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='ORDERNUMBER'>

# %%
df['COUNTRY'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='COUNTRY'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2747 entries, 0 to 2746
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ORDERNUMBER           2747 non-null   int64
#  1   QUANTITYORDERED       2747 non-null   int64
#  2   PRICEEACH             2747 non-null   float64
#  3   ORDERLINENUMBER       2747 non-null   int64
#  4   SALES                 2747 non-null   float64
#  5   ORDERDATE             2747 non-null   object
#  6   DAYS_SINCE_LASTORDER  2747 non-null   int64
#  7   STATUS                2747 non-null   object
#  8   PRODUCTLINE           2747 non-null   object
#  9   MSRP                  2747 non-null   int64
#  10  PRODUCTCODE           2747 non-null   object
#  11  CUSTOMERNAME          2747 non-null   object
#  12  PHONE                 2747 non-null   object
#  13  ADDRESSLINE1          2747 non-null   object
#  14  CITY                  2747 non-null   object
# ...

# %%
df['PRICEEACH'].plot.hist(bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['PRICEEACH'].describe()
# Out:
# count    2747.000000
# mean      101.098952
# std        42.042549
# min        26.880000
# 25%        68.745000
# 50%        95.550000
# 75%       127.100000
# max       252.870000
# Name: PRICEEACH, dtype: float64

# %%
df['STATUS'].value_counts().plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
df.loc[1:23,['COUNTRY','STATUS']].apply(pd.Series.value_counts).plot.pie(subplots=True)
# Out:
# array([<Axes: ylabel='COUNTRY'>, <Axes: ylabel='STATUS'>], dtype=object)

# %%
import plotly.express as px

# %%
count = df['STATUS'].value_counts()

# %%
fig = px.bar(count,x=count.index,y=count.values)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
percentage = df.loc[1:5,['SALES']]/df.loc[1:5,['SALES']].sum()*100
print(percentage)
perc = percentage['SALES'].to_numpy()
print(perc)
# Out:
#        SALES
# 1  16.891539
# 2  23.721928
# 3  22.881351
# 4  21.251131
# 5  15.254051
# [16.89153908 23.7219281  22.88135127 21.25113057 15.25405097]

# %%
fig = px.pie(values = perc, hole = 0.5,title='Porcentagem')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
percentage_Cat = df['PRODUCTLINE'].value_counts()/df['PRODUCTLINE'].value_counts().sum()*100
print(percentage_Cat)
# Out:
# PRODUCTLINE
# Classic Cars        34.546778
# Vintage Cars        21.077539
# Motorcycles         11.394248
# Planes              11.066618
# Trucks and Buses    10.738988
# Ships                8.372770
# Trains               2.803058
# Name: count, dtype: float64

# %%
fig=px.pie(values=perc_cat,names=percentage_Cat.index,hole=0.3,title='Porcentagem')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.graph_objects as go

con_count = df['COUNTRY'].value_counts()[:5]
others = df['COUNTRY'].value_counts()[6:].sum()
con_count['Outros'] = others
con_count

fig = go.Figure(go.Funnel(y=con_count.index, x=con_count.values))
fig.update_layout(template='plotly_white')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import seaborn as sns

# %%
sns.histplot(df[['PRICEEACH']],bins=20,kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.boxplot(df['PRICEEACH'])
# Out:
# <Axes: ylabel='PRICEEACH'>

# %%
df_num = df.select_dtypes(include=['int64','float64']).drop(columns=['ORDERNUMBER','ORDERLINENUMBER','QUANTITYORDERED'])
df_num
# Out:
#       PRICEEACH    SALES  DAYS_SINCE_LASTORDER  MSRP
# 0         95.70  2871.00                   828    95
# 1         81.35  2765.90                   757    95
# 2         94.74  3884.34                   703    95
# 3         83.26  3746.70                   649    95
# 4         96.66  3479.76                   586    95
# ...         ...      ...                   ...   ...
# 2742     112.22  2244.40                  2924    54
# 2743     137.19  3978.51                  2865    54
# 2744     125.99  5417.57                  2836    54
# 2745      62.24  2116.16                  2810    54
# 2746      65.52  3079.44                  2772    54
#
# [2747 rows x 4 columns]

# %%
sns.pairplot(data=df_num,corner=True)

# %%
df['ORDERDATE']=pd.to_datetime(df['ORDERDATE'],dayfirst=True)
df['YEAR'] = pd.to_datetime(df['ORDERDATE'],dayfirst=True).dt.year

# %%
sns.lineplot(data=df,x='ORDERDATE',y='SALES',hue='YEAR')
# Out:
# <Axes: xlabel='ORDERDATE', ylabel='SALES'>
